# %%
import numpy as np
import pandas as pd
import pickle
import matplotlib.pyplot as plt

# %%
def open_file():
    with open('ddata_min.pickle', 'rb') as f:
        f_data = pickle.load(f)
    return f_data

# %%
def coin_select(name='BTC'):
    f_data = open_file()
    coin_name = name
    s_coin_data = f_data[f_data.permno == coin_name].copy()
    s_coin_data = s_coin_data.reset_index()
    
    return s_coin_data

# %%
def RSI(period=30, name='BTC'):
    s_coin_data = coin_select(name=name)
    period = period
    U = np.where(s_coin_data.prc.diff(1) > 0, s_coin_data.prc.diff(1), 0)
    D = np.where(s_coin_data.prc.diff(1) < 0, s_coin_data.prc.diff(1)*(-1), 0)
    AU = pd.DataFrame(U, index=s_coin_data.index).rolling(window=period).mean()
    AD = pd.DataFrame(D, index=s_coin_data.index).rolling(window=period).mean()
    RSI = AU / (AD+AU) * 100
    s_coin_data['RSI'] = RSI
    
    return s_coin_data['RSI']

# %%
def MACD(n_short=30, n_long=60, n_signal=6, name='BTC'):
    s_coin_data = coin_select(name=name)
    EMA_short = s_coin_data['prc'].ewm(span=n_short, min_periods=n_short-1).mean()
    EMA_long = s_coin_data['prc'].ewm(span=n_long, min_periods=n_long-1).mean()
    
    s_coin_data['MACD'] = EMA_short - EMA_long
    s_coin_data['MACD_signal'] = s_coin_data['MACD'].ewm(span=n_signal, min_periods=n_signal-1).mean()
    s_coin_data['MACD_diff'] = s_coin_data['MACD'] - s_coin_data['MACD_signal']
    
    return s_coin_data['MACD'], s_coin_data['MACD_signal'], s_coin_data['MACD_diff']

# %%
def VWAP(window=300, name='BTC'):
    s_coin_data = coin_select(name=name)
    df_tvol = s_coin_data.tvol.rolling(window=window).sum()
    df_prc_mul_tvol = (s_coin_data.prc*s_coin_data.tvol).rolling(window=window).sum()
    s_coin_data['VWAP'] = df_prc_mul_tvol / df_tvol
    
    return s_coin_data['VWAP']

# %%
def base_df(name='BTC'):
    s_coin_data = coin_select(name=name)
    s_coin_data = s_coin_data.join(RSI())
    s_coin_data = s_coin_data.join(VWAP())
    s_coin_data = s_coin_data.join(MACD())
    
    return s_coin_data

# %%
def rsi_trading_test(initial_asset=100, sell_fee=0.0004, buy_fee=0.0004):
    
    df_result = pd.DataFrame(columns=['Period', 'Final Asset', 'Winning', 'Losing'])
    s_coin_data = coin_select(name='BTC')
    
    for i in range(100, 201):
        period = i
        print('RSI period is {}'.format(period))
        
        s_coin_data['RSI'] = RSI(period=i)

        buy_price = 0
#         total_profit = 0
#         total_loss = 0
        win_count = 0
        lose_count = 0
        sell_signal = False
        asset = initial_asset
        sell_fee = sell_fee
        buy_fee = buy_fee
        position = False

        for i, row in s_coin_data.iterrows():
            date, price, rsi = row['date'], row['prc'], row['RSI']

            if sell_signal:
                # 수익률
                profit_pct = (price - buy_price) / buy_price - sell_fee
#                 s_coin_data.at[i, 'Profit'] = profit_pct * asset
                asset *= (1+profit_pct)

                #초기화
                buy_price = 0
                position = False
                sell_signal = False

                # 이익
                if profit_pct > 0:
                    win_count += 1
#                     total_profit += profit_pct * asset

                # 손실
                else:
                    lose_count += 1
#                     total_loss += profit_pct * asset


    #             print('SELL: {} | Sell price: {:7.2f} | Total asset: {:7.4f}'.format(date, price, asset), '\n')


            # Buy signal
            elif not(buy_price and position) and rsi <= 30:
                asset = asset * (1-buy_fee)
                buy_price = s_coin_data.prc[i]
                position = True

    #             print('BUY: {} | Buy price: {:7.2f} | Total asset: {:7.4f}'.format(date, buy_price, asset))

            # Sell signal
            elif (position and buy_price) and rsi >= 70:
                sell_signal = True

            elif asset <= 0:
                break

        df_result.loc[period] = [period, asset, win_count, lose_count]
        print('Final Asset: {:10.4f} | Winning Trade: {:7} | Losing Trade: {:7}'.
                    format(asset, win_count, lose_count))
    
    return df_result

# %%
rsi_trading_test()
# Out:
# RSI period is 10
# Final Asset:     0.0013 | Winning Trade:   11065 | Losing Trade:    7813
# RSI period is 11
# Final Asset:     0.0087 | Winning Trade:    9712 | Losing Trade:    6588
# RSI period is 12
# Final Asset:     0.0413 | Winning Trade:    8626 | Losing Trade:    5670
# RSI period is 13
# Final Asset:     0.2008 | Winning Trade:    7693 | Losing Trade:    4892
# RSI period is 14
# Final Asset:     0.4479 | Winning Trade:    6953 | Losing Trade:    4167
# RSI period is 15
# Final Asset:     0.8955 | Winning Trade:    6149 | Losing Trade:    3618
# RSI period is 16
# Final Asset:     1.6592 | Winning Trade:    5486 | Losing Trade:    3197
# RSI period is 17
# Final Asset:     3.9045 | Winning Trade:    4895 | Losing Trade:    2847
# RSI period is 18
# Final Asset:     4.6182 | Winning Trade:    4430 | Losing Trade:    2502
# RSI period is 19
# Final Asset:     6.2468 | Winning Trade:    3955 | Losing Trade:    2214
# RSI period is 20
# Final Asset:    13.0261 | Winning Trade:    3588 | Losing Trade:    1957
# RSI period is 21
# Final Asset:    16.8082 | Winning Trade:    3184 | Losing Trade:    1766
# RSI period is 22
# Final Asset:    15.5918 | Winning Trade:    2929 | Losing Trade:    1564
# RSI period is 23
# Final Asset:    20.4812 | Winning Trade:    2621 | Losing Trade:    1381
# RSI period is 24
# Final Asset:    34.6134 | Winning Trade:    2340 | Losing Trade:    1269
# RSI period is 25
# Final Asset:    49.9834 | Winning Trade:    2065 | Losing Trade:    1155
# RSI period is 26
# Final Asset:    38.4908 | Winning Trade:    1875 | Losing Trade:    1022
# RSI period is 27
# Final Asset:    46.4590 | Winning Trade:    1680 | Losing Trade:     932
# RSI period is 28
# Final Asset:    57.4819 | Winning Trade:    1509 | Losing Trade:     841
# RSI period is 29
# Final Asset:    69.7366 | Winning Trade:    1377 | Losing Trade:     742
# RSI period is 30
# Final Asset:    75.7671 | Winning Trade:    1252 | Losing Trade:     650
# RSI period is 31
# Final Asset:    93.5865 | Winning Trade:    1164 | Losing Trade:     583
# RSI period is 32
# Final Asset:   135.9898 | Winning Trade:    1065 | Losing Trade:     522
# RSI period is 33
# Final Asset:   133.7564 | Winning Trade:     966 | Losing Trade:     492
# RSI period is 34
# Final Asset:   213.6174 | Winning Trade:     909 | Losing Trade:     425
# RSI period is 35
# Final Asset:   152.7458 | Winning Trade:     812 | Losing Trade:     391
# RSI period is 36
# Final Asset:   164.4527 | Winning Trade:     744 | Losing Trade:     349
# RSI period is 37
# Final Asset:   144.2067 | Winning Trade:     671 | Losing Trade:     321
# RSI period is 38
# Final Asset:   124.6883 | Winning Trade:     600 | Losing Trade:     293
# RSI period is 39
# Final Asset:   112.0953 | Winning Trade:     548 | Losing Trade:     273
# RSI period is 40
# Final Asset:    56.8612 | Winning Trade:     475 | Losing Trade:     251
# RSI period is 41
# Final Asset:    68.8212 | Winning Trade:     453 | Losing Trade:     227
# RSI period is 42
# Final Asset:   110.3227 | Winning Trade:     415 | Losing Trade:     220
# RSI period is 43
# Final Asset:   116.6647 | Winning Trade:     383 | Losing Trade:     211
# RSI period is 44
# Final Asset:   135.3847 | Winning Trade:     355 | Losing Trade:     186
# RSI period is 45
# Final Asset:   116.5002 | Winning Trade:     329 | Losing Trade:     171
# RSI period is 46
# Final Asset:   126.1503 | Winning Trade:     314 | Losing Trade:     153
# RSI period is 47
# Final Asset:   103.3518 | Winning Trade:     282 | Losing Trade:     145
# RSI period is 48
# Final Asset:    75.5090 | Winning Trade:     241 | Losing Trade:     148
# RSI period is 49
# Final Asset:    79.0858 | Winning Trade:     227 | Losing Trade:     139
# RSI period is 50
# Final Asset:    78.8644 | Winning Trade:     210 | Losing Trade:     126
# RSI period is 51
# Final Asset:   122.1701 | Winning Trade:     203 | Losing Trade:     112
# RSI period is 52
# Final Asset:   129.2515 | Winning Trade:     190 | Losing Trade:     107
# RSI period is 53
# Final Asset:   119.7870 | Winning Trade:     175 | Losing Trade:     101
# RSI period is 54
# Final Asset:   133.3243 | Winning Trade:     167 | Losing Trade:      92
# RSI period is 55
# Final Asset:   123.1899 | Winning Trade:     150 | Losing Trade:      95
# RSI period is 56
# Final Asset:   153.2544 | Winning Trade:     144 | Losing Trade:      87
# RSI period is 57
# Final Asset:   135.2837 | Winning Trade:     141 | Losing Trade:      83
# RSI period is 58
# Final Asset:   115.8247 | Winning Trade:     124 | Losing Trade:      79
# RSI period is 59
# Final Asset:    77.9401 | Winning Trade:     122 | Losing Trade:      74
# RSI period is 60
# Final Asset:    46.0369 | Winning Trade:     106 | Losing Trade:      72
# RSI period is 61
# Final Asset:    52.0992 | Winning Trade:     101 | Losing Trade:      63
# RSI period is 62
# Final Asset:    65.5893 | Winning Trade:      98 | Losing Trade:      66
# RSI period is 63
# Final Asset:    95.2084 | Winning Trade:      89 | Losing Trade:      64
# RSI period is 64
# Final Asset:    95.4487 | Winning Trade:      86 | Losing Trade:      60
# RSI period is 65
# Final Asset:    79.8543 | Winning Trade:      80 | Losing Trade:      53
# RSI period is 66
# Final Asset:   106.9465 | Winning Trade:      81 | Losing Trade:      49
# RSI period is 67
# Final Asset:   123.6344 | Winning Trade:      80 | Losing Trade:      41
# RSI period is 68
# Final Asset:    83.3467 | Winning Trade:      76 | Losing Trade:      40
# RSI period is 69
# Final Asset:   101.9050 | Winning Trade:      72 | Losing Trade:      40
# RSI period is 70
# Final Asset:    77.2477 | Winning Trade:      60 | Losing Trade:      40
# RSI period is 71
# Final Asset:    84.6164 | Winning Trade:      58 | Losing Trade:      38
# RSI period is 72
# Final Asset:   110.4844 | Winning Trade:      53 | Losing Trade:      40
# RSI period is 73
# Final Asset:    90.3450 | Winning Trade:      51 | Losing Trade:      37
# RSI period is 74
# Final Asset:    96.2658 | Winning Trade:      46 | Losing Trade:      35
# RSI period is 75
# Final Asset:   109.5459 | Winning Trade:      50 | Losing Trade:      32
# RSI period is 76
# Final Asset:   116.6997 | Winning Trade:      45 | Losing Trade:      33
# RSI period is 77
# Final Asset:   103.4721 | Winning Trade:      47 | Losing Trade:      29
# RSI period is 78
# Final Asset:   112.5355 | Winning Trade:      42 | Losing Trade:      30
# RSI period is 79
# Final Asset:   193.1709 | Winning Trade:      43 | Losing Trade:      28
# RSI period is 80
# Final Asset:   166.1099 | Winning Trade:      41 | Losing Trade:      28
# RSI period is 81
# Final Asset:   188.8538 | Winning Trade:      41 | Losing Trade:      24
# RSI period is 82
# Final Asset:   174.3392 | Winning Trade:      37 | Losing Trade:      25
# RSI period is 83
# Final Asset:   114.2724 | Winning Trade:      34 | Losing Trade:      26
# RSI period is 84
# Final Asset:   208.1488 | Winning Trade:      37 | Losing Trade:      22
# RSI period is 85
# Final Asset:   197.8015 | Winning Trade:      35 | Losing Trade:      20
# RSI period is 86
# Final Asset:   199.1017 | Winning Trade:      33 | Losing Trade:      18
# RSI period is 87
# Final Asset:   185.7787 | Winning Trade:      32 | Losing Trade:      20
# RSI period is 88
# Final Asset:   190.0164 | Winning Trade:      27 | Losing Trade:      21
# RSI period is 89
# Final Asset:   291.8634 | Winning Trade:      31 | Losing Trade:      16
# RSI period is 90
# Final Asset:   196.5951 | Winning Trade:      29 | Losing Trade:      15
# RSI period is 91
# Final Asset:   154.7789 | Winning Trade:      25 | Losing Trade:      17
# RSI period is 92
# Final Asset:   198.8598 | Winning Trade:      24 | Losing Trade:      18
# RSI period is 93
# Final Asset:   236.2061 | Winning Trade:      25 | Losing Trade:      16
# RSI period is 94
# Final Asset:   198.2582 | Winning Trade:      25 | Losing Trade:      15
# RSI period is 95
# Final Asset:   179.2763 | Winning Trade:      25 | Losing Trade:      14
# RSI period is 96
# Final Asset:   206.7794 | Winning Trade:      27 | Losing Trade:      15
# RSI period is 97
# Final Asset:   241.0984 | Winning Trade:      21 | Losing Trade:      16
# RSI period is 98
# Final Asset:   210.8577 | Winning Trade:      25 | Losing Trade:      12
# RSI period is 99
# Final Asset:   223.2803 | Winning Trade:      22 | Losing Trade:      12
# RSI period is 100
# Final Asset:   253.2899 | Winning Trade:      23 | Losing Trade:      11
#      Period  Final Asset  Winning  Losing
# 10     10.0     0.001257  11065.0  7813.0
# 11     11.0     0.008653   9712.0  6588.0
# 12     12.0     0.041329   8626.0  5670.0
# 13     13.0     0.200819   7693.0  4892.0
# 14     14.0     0.447908   6953.0  4167.0
# ..      ...          ...      ...     ...
# 96     96.0   206.779411     27.0    15.0
# 97     97.0   241.098447     21.0    16.0
# 98     98.0   210.857676     25.0    12.0
# 99     99.0   223.280313     22.0    12.0
# 100   100.0   253.289889     23.0    11.0
#
# [91 rows x 4 columns]

# %%
import itertools
def macd_trading_test(initial_asset=100, sell_fee=0.0004, buy_fee=0.0004):
    
    n_short = range(30, 300)
    n_long = range(3, 5)
    n_signal = range(4, 10)
    sls = list(itertools.product(n_short, n_long, n_signal))
    
    index = -1
    
    s_coin_data = coin_select(name='BTC')
    df_result = pd.DataFrame(columns=['Feature', 'Final Asset', 'Winning', 'Losing'])
    
    for i in sls:
        index += 1
        n_short = i[0]
        n_long = i[1] * i[0]
        n_signal = i[2]
        print('MACD feature | short: {}, long: {}, signal: {}'.format(n_short, n_long, n_signal))
        
        s_coin_data['MACD'], s_coin_data['MACD_signal'], s_coin_data['MACD_diff'] = MACD(n_short=n_short, n_long=n_long, n_signal=n_signal)

        buy_price = 0
#         total_profit = 0
#         total_loss = 0
        win_count = 0
        lose_count = 0
        sell_signal = False
        asset = initial_asset
        sell_fee = sell_fee
        buy_fee = buy_fee
        position = False

        for i, row in s_coin_data.iterrows():
            date, price, macd_diff = row['date'], row['prc'], row['MACD_diff']

            if sell_signal:
                # 수익률
                profit_pct = (price - buy_price) / buy_price - sell_fee
#                 s_coin_data.at[i, 'Profit'] = profit_pct * asset
                asset *= (1+profit_pct)

                #초기화
                buy_price = 0
                position = False
                sell_signal = False

                # 이익
                if profit_pct > 0:
                    win_count += 1
#                     total_profit += profit_pct * asset

                # 손실
                else:
                    lose_count += 1
#                     total_loss += profit_pct * asset


    #             print('SELL: {} | Sell price: {:7.2f} | Total asset: {:7.4f}'.format(date, price, asset), '\n')


            # Buy signal
            elif not(buy_price and position) and macd_diff > 0:
                asset = asset * (1-buy_fee)
                buy_price = s_coin_data.prc[i]
                position = True

    #             print('BUY: {} | Buy price: {:7.2f} | Total asset: {:7.4f}'.format(date, buy_price, asset))

            # Sell signal
            elif (position and buy_price) and macd_diff <= 0:
                sell_signal = True

            elif asset <= 0:
                break

        df_result.loc[index] = [i, asset, win_count, lose_count]
        print('Final Asset: {:10.4f} | Winning Trade: {:7} | Losing Trade: {:7}'.
                    format(asset, win_count, lose_count))
    
    return df_result

# %%
def vwap_trading_test(initial_asset=100, sell_fee=0.0004, buy_fee=0.0004):
    
    df_result = pd.DataFrame(columns=['Window', 'Final Asset', 'Winning', 'Losing'])
    s_coin_data = coin_select(name='BTC')
    
    
    for i in range(400, 601, 5):
        window = i
        print('VWAP Window is {}'.format(window))
        
        s_coin_data['VWAP'] = VWAP(window=window)

        buy_price = 0
#         total_profit = 0
#         total_loss = 0
        win_count = 0
        lose_count = 0
        sell_signal = False
        asset = initial_asset
        sell_fee = sell_fee
        buy_fee = buy_fee
        position = False

        for i, row in s_coin_data.iterrows():
            date, price, vwap = row['date'], row['prc'], row['VWAP']

            if sell_signal:
                # 수익률
                profit_pct = (price - buy_price) / buy_price - sell_fee
#                 s_coin_data.at[i, 'Profit'] = profit_pct * asset
                asset *= (1+profit_pct)

                #초기화
                buy_price = 0
                position = False
                sell_signal = False

                # 이익
                if profit_pct > 0:
                    win_count += 1
#                     total_profit += profit_pct * asset

                # 손실
                else:
                    lose_count += 1
#                     total_loss += profit_pct * asset


    #             print('SELL: {} | Sell price: {:7.2f} | Total asset: {:7.4f}'.format(date, price, asset), '\n')


            # Buy signal
            elif not(buy_price and position) and (price/vwap > 1):
                asset = asset * (1-buy_fee)
                buy_price = s_coin_data.prc[i]
                position = True

    #             print('BUY: {} | Buy price: {:7.2f} | Total asset: {:7.4f}'.format(date, buy_price, asset))

            # Sell signal
            elif (position and buy_price) and (price/vwap <= 1):
                sell_signal = True

            elif asset <= 0:
                break

        df_result.loc[window] = [window, asset, win_count, lose_count]
        print('Final Asset: {:10.4f} | Winning Trade: {:7} | Losing Trade: {:7}'.
                    format(asset, win_count, lose_count))
    
    return df_result

# %%
vwap_result = vwap_trading_test()
rsi_result = rsi_trading_test()
macd_result = macd_trading_test()
# Out:
# VWAP Window is 400
# Final Asset:     0.0018 | Winning Trade:    1859 | Losing Trade:   11651
# VWAP Window is 405
# Final Asset:     0.0017 | Winning Trade:    1840 | Losing Trade:   11587
# VWAP Window is 410
# Final Asset:     0.0018 | Winning Trade:    1815 | Losing Trade:   11604
# VWAP Window is 415
# Final Asset:     0.0018 | Winning Trade:    1826 | Losing Trade:   11531
# VWAP Window is 420
# Final Asset:     0.0019 | Winning Trade:    1794 | Losing Trade:   11496
# VWAP Window is 425
# Final Asset:     0.0019 | Winning Trade:    1781 | Losing Trade:   11457
# VWAP Window is 430
# Final Asset:     0.0018 | Winning Trade:    1737 | Losing Trade:   11460
# VWAP Window is 435
# Final Asset:     0.0020 | Winning Trade:    1720 | Losing Trade:   11386
# VWAP Window is 440
# Final Asset:     0.0021 | Winning Trade:    1700 | Losing Trade:   11335
# VWAP Window is 445
# Final Asset:     0.0021 | Winning Trade:    1735 | Losing Trade:   11291
# VWAP Window is 450
# Final Asset:     0.0021 | Winning Trade:    1709 | Losing Trade:   11201
# VWAP Window is 455
# Final Asset:     0.0021 | Winning Trade:    1686 | Losing Trade:   11169
# VWAP Window is 460
# Final Asset:     0.0026 | Winning Trade:    1696 | Losing Trade:   11073
# VWAP Window is 465
# Final Asset:     0.0025 | Winning Trade:    1703 | Losing Trade:   11063
# VWAP Window is 470
# Final Asset:     0.0025 | Winning Trade:    1670 | Losing Trade:   11066
# VWAP Window is 475
# Final Asset:     0.0024 | Winning Trade:    1688 | Losing Trade:   11059
# VWAP Window is 480
# Final Asset:     0.0024 | Winning Trade:    1660 | Losing Trade:   11003
# VWAP Window is 485
# Final Asset:     0.0025 | Winning Trade:    1640 | Losing Trade:   10948
# VWAP Window is 490
# Final Asset:     0.0028 | Winning Trade:    1644 | Losing Trade:   10886
# VWAP Window is 495
# Final Asset:     0.0030 | Winning Trade:    1644 | Losing Trade:   10866
# Final Asset:   136.0517 | Winning Trade:      15 | Losing Trade:      11
# RSI period is 112
# Final Asset:   151.1481 | Winning Trade:      13 | Losing Trade:      11
# RSI period is 113
# Final Asset:   138.4764 | Winning Trade:      14 | Losing Trade:      11
# RSI period is 114
# Final Asset:   132.5600 | Winning Trade:      15 | Losing Trade:      10
# RSI period is 115
# Final Asset:   135.2030 | Winning Trade:      14 | Losing Trade:      10
# RSI period is 116
# Final Asset:   180.1671 | Winning Trade:      14 | Losing Trade:      10
# RSI period is 117
# Final Asset:   189.5412 | Winning Trade:      15 | Losing Trade:       9
# RSI period is 118
# Final Asset:   228.6749 | Winning Trade:      16 | Losing Trade:       7
# RSI period is 119
# Final Asset:   145.9475 | Winning Trade:      14 | Losing Trade:       9
# RSI period is 120
# Final Asset:   152.6011 | Winning Trade:      15 | Losing Trade:       7
# RSI period is 121
# Final Asset:   151.9032 | Winning Trade:      13 | Losing Trade:       9
# RSI period is 122
# Final Asset:   228.8882 | Winning Trade:      13 | Losing Trade:       8
# RSI period is 123
# Final Asset:   226.2154 | Winning Trade:      16 | Losing Trade:       6
# RSI period is 124
# Final Asset:   241.1902 | Winning Trade:      15 | Losing Trade:       7
# RSI period is 125
# Final Asset:   259.3412 | Winning Trade:      15 | Losing Trade:       7
# RSI period is 126
# Final Asset:   249.9111 | Winning Trade:      14 | Losing Trade:       7
# RSI period is 127
# Final Asset:   249.6800 | Winning Trade:      14 | Losing Trade:       7
# RSI period is 128
# Final Asset:   233.4924 | Winning Trade:      13 | Losing Trade:       7
# RSI period is 129
# Final Asset:   237.3978 | Winning Trade:      12 | Losing Trade:       7
# RSI period is 130
# Final Asset:   244.8804 | Winning Trade:      13 | Losing Trade:       7
# RSI period is 131
# Final Asset:   534.5269 | Winning Trade:      13 | Losing Trade:       6
# RSI period is 132
# Final Asset:   349.1315 | Winning Trade:      13 | Losing Trade:       5
# RSI period is 133
# Final Asset:   335.5583 | Winning Trade:      11 | Losing Trade:       5
# RSI period is 134
# Final Asset:   330.1223 | Winning Trade:      12 | Losing Trade:       5
# RSI period is 135
# Final Asset:   510.1362 | Winning Trade:      12 | Losing Trade:       5
# RSI period is 136
# Final Asset:   511.7107 | Winning Trade:      12 | Losing Trade:       5
# RSI period is 137
# Final Asset:   570.2891 | Winning Trade:      13 | Losing Trade:       4
# RSI period is 138
# Final Asset:   581.8568 | Winning Trade:      13 | Losing Trade:       4
# RSI period is 139
# Final Asset:   511.9403 | Winning Trade:      13 | Losing Trade:       3
# RSI period is 140
# Final Asset:   525.8363 | Winning Trade:      13 | Losing Trade:       3
# RSI period is 141
# Final Asset:   572.9618 | Winning Trade:      12 | Losing Trade:       3
# RSI period is 142
# Final Asset:   578.1105 | Winning Trade:      11 | Losing Trade:       3
# RSI period is 143
# Final Asset:   574.7049 | Winning Trade:      11 | Losing Trade:       3
# RSI period is 144
# Final Asset:   551.5463 | Winning Trade:      12 | Losing Trade:       2
# RSI period is 145
# Final Asset:   658.8749 | Winning Trade:      12 | Losing Trade:       2
# RSI period is 146
# Final Asset:   654.0111 | Winning Trade:      12 | Losing Trade:       2
# RSI period is 147
# Final Asset:   600.7232 | Winning Trade:      12 | Losing Trade:       2
# RSI period is 148
# Final Asset:   638.7425 | Winning Trade:      11 | Losing Trade:       2
# RSI period is 149
# Final Asset:   638.7425 | Winning Trade:      11 | Losing Trade:       2
# RSI period is 150
# Final Asset:   641.2880 | Winning Trade:      11 | Losing Trade:       2
# RSI period is 151
# Final Asset:   638.5214 | Winning Trade:      11 | Losing Trade:       2
# RSI period is 152
# Final Asset:   621.2440 | Winning Trade:      10 | Losing Trade:       2
# RSI period is 153
# Final Asset:   636.8867 | Winning Trade:      11 | Losing Trade:       1
# RSI period is 154
# Final Asset:   649.0859 | Winning Trade:      11 | Losing Trade:       1
# RSI period is 155
# Final Asset:   636.6551 | Winning Trade:      10 | Losing Trade:       1
# RSI period is 156
# Final Asset:   628.4947 | Winning Trade:      10 | Losing Trade:       2
# RSI period is 157
# Final Asset:   619.6116 | Winning Trade:       9 | Losing Trade:       2
# RSI period is 158
# Final Asset:   520.0785 | Winning Trade:       9 | Losing Trade:       1
# RSI period is 159
# Final Asset:   526.6704 | Winning Trade:      10 | Losing Trade:       1
# RSI period is 160
# Final Asset:   532.5596 | Winning Trade:      10 | Losing Trade:       1
# RSI period is 161
# Final Asset:   532.4091 | Winning Trade:       9 | Losing Trade:       1
# RSI period is 162
# Final Asset:   532.4091 | Winning Trade:       9 | Losing Trade:       1
# RSI period is 163
# Final Asset:   521.5686 | Winning Trade:       9 | Losing Trade:       1
# RSI period is 164
# Final Asset:   559.4870 | Winning Trade:       9 | Losing Trade:       1
# RSI period is 165
# Final Asset:   571.8239 | Winning Trade:       9 | Losing Trade:       1
# RSI period is 166
# Final Asset:   147.1360 | Winning Trade:       8 | Losing Trade:       1
# RSI period is 167
# Final Asset:   147.1360 | Winning Trade:       8 | Losing Trade:       1
# RSI period is 168
# Final Asset:   557.0695 | Winning Trade:       9 | Losing Trade:       1
# RSI period is 169
# Final Asset:   557.3201 | Winning Trade:       9 | Losing Trade:       1
# RSI period is 170
# Final Asset:   183.2158 | Winning Trade:       7 | Losing Trade:       1
# RSI period is 171
# Final Asset:   183.2601 | Winning Trade:       7 | Losing Trade:       1
# RSI period is 172
# Final Asset:   173.2532 | Winning Trade:       6 | Losing Trade:       1
# RSI period is 173
# Final Asset:   172.4905 | Winning Trade:       5 | Losing Trade:       1
# RSI period is 174
# Final Asset:   172.5269 | Winning Trade:       5 | Losing Trade:       1
# RSI period is 175
# Final Asset:   183.1366 | Winning Trade:       6 | Losing Trade:       1
# RSI period is 176
# Final Asset:   182.9019 | Winning Trade:       6 | Losing Trade:       1
# RSI period is 177
# Final Asset:   175.3488 | Winning Trade:       6 | Losing Trade:       1
# RSI period is 178
# Final Asset:   166.4117 | Winning Trade:       6 | Losing Trade:       1
# RSI period is 179
# Final Asset:   156.8772 | Winning Trade:       4 | Losing Trade:       1
# RSI period is 180
# Final Asset:    84.2385 | Winning Trade:       2 | Losing Trade:       2
# RSI period is 181
# Final Asset:    88.2387 | Winning Trade:       3 | Losing Trade:       2
# RSI period is 182
# Final Asset:    89.0147 | Winning Trade:       3 | Losing Trade:       2
# RSI period is 183
# Final Asset:    89.0147 | Winning Trade:       3 | Losing Trade:       2
# RSI period is 184
# Final Asset:    89.0147 | Winning Trade:       3 | Losing Trade:       2
# RSI period is 185
# Final Asset:    89.0147 | Winning Trade:       3 | Losing Trade:       2
# RSI period is 186
# Final Asset:   138.0268 | Winning Trade:       5 | Losing Trade:       1
# RSI period is 187
# Final Asset:   138.0268 | Winning Trade:       5 | Losing Trade:       1
# RSI period is 188
# Final Asset:   148.0451 | Winning Trade:       6 | Losing Trade:       1
# RSI period is 189
# Final Asset:    91.1157 | Winning Trade:       3 | Losing Trade:       2
# RSI period is 190
# Final Asset:    91.1472 | Winning Trade:       3 | Losing Trade:       2
# RSI period is 191
# Final Asset:    92.5096 | Winning Trade:       3 | Losing Trade:       2
# RSI period is 192
# Final Asset:    88.0749 | Winning Trade:       2 | Losing Trade:       3
# RSI period is 193
# Final Asset:    85.9051 | Winning Trade:       2 | Losing Trade:       2
# RSI period is 194
# Final Asset:    82.1433 | Winning Trade:       1 | Losing Trade:       3
# RSI period is 195
# Final Asset:    85.9051 | Winning Trade:       2 | Losing Trade:       2
# RSI period is 196
# Final Asset:    82.1433 | Winning Trade:       1 | Losing Trade:       3
# RSI period is 197
# Final Asset:    82.2956 | Winning Trade:       1 | Losing Trade:       3
# RSI period is 198
# Final Asset:    86.4093 | Winning Trade:       2 | Losing Trade:       2
# RSI period is 199
# Final Asset:    82.6673 | Winning Trade:       1 | Losing Trade:       3
# RSI period is 200
# Final Asset:    82.9987 | Winning Trade:       1 | Losing Trade:       3
# MACD feature | short: 30, long: 90, signal: 4
# Final Asset:     0.0000 | Winning Trade:    7980 | Losing Trade:   23114
# MACD feature | short: 30, long: 90, signal: 5
# Final Asset:     0.0000 | Winning Trade:    7334 | Losing Trade:   20785
# MACD feature | short: 30, long: 90, signal: 6
# Final Asset:     0.0000 | Winning Trade:    6918 | Losing Trade:   19098
# MACD feature | short: 30, long: 90, signal: 7
# Final Asset:     0.0000 | Winning Trade:    6587 | Losing Trade:   17737
# MACD feature | short: 30, long: 90, signal: 8
# Final Asset:     0.0000 | Winning Trade:    6325 | Losing Trade:   16598
# MACD feature | short: 30, long: 90, signal: 9
# Final Asset:     0.0000 | Winning Trade:    6059 | Losing Trade:   15734
# MACD feature | short: 30, long: 120, signal: 4
# Final Asset:     0.0000 | Winning Trade:    7599 | Losing Trade:   22628
# MACD feature | short: 30, long: 120, signal: 5
# Final Asset:     0.0000 | Winning Trade:    7031 | Losing Trade:   20258
# MACD feature | short: 30, long: 120, signal: 6
# Final Asset:     0.0000 | Winning Trade:    6606 | Losing Trade:   18549
# MACD feature | short: 30, long: 120, signal: 7
# Final Asset:     0.0000 | Winning Trade:    6257 | Losing Trade:   17288
# MACD feature | short: 30, long: 120, signal: 8
# Final Asset:     0.0000 | Winning Trade:    5953 | Losing Trade:   16228
# MACD feature | short: 30, long: 120, signal: 9
# Final Asset:     0.0000 | Winning Trade:    5699 | Losing Trade:   15388
# MACD feature | short: 31, long: 93, signal: 4
# Final Asset:     0.0000 | Winning Trade:    
signal: 5
# Final Asset:     0.0000 | Winning Trade:    3707 | Losing Trade:   13278
# MACD feature | short: 78, long: 312, signal: 6
# Final Asset:     0.0002 | Winning Trade:    3512 | Losing Trade:   12023
# MACD feature | short: 78, long: 312, signal: 7
# Final Asset:     0.0005 | Winning Trade:    3389 | Losing Trade:   11114
# MACD feature | short: 78, long: 312, signal: 8
# Final Asset:     0.0011 | Winning Trade:    3231 | Losing Trade:   10366
# MACD feature | short: 78, long: 312, signal: 9
# Final Asset:     0.0026 | Winning Trade:    3112 | Losing Trade:    9713
# MACD feature | short: 79, long: 237, signal: 4
# Final Asset:     0.0000 | Winning Trade:    4196 | Losing Trade:   15233
# MACD feature | short: 79, long: 237, signal: 5
# Final Asset:     0.0000 | Winning Trade:    3865 | Losing Trade:   13672
# MACD feature | short: 79, long: 237, signal: 6
# Final Asset:     0.0001 | Winning Trade:    3671 | Losing Trade:   12407
# MACD feature | short: 79, long: 237, signal: 7
# Final Asset:     0.0002 | Winning Trade:    3500 | Losing Trade:   11453
# MACD feature | short: 79, long: 237, signal: 8
# Final Asset:     0.0005 | Winning Trade:    3356 | Losing Trade:   10731
# MACD feature | short: 79, long: 237, signal: 9
# Final Asset:     0.0010 | Winning Trade:    3235 | Losing Trade:   10066
# MACD feature | short: 79, long: 316, signal: 4
# Final Asset:     0.0000 | Winning Trade:    3972 | Losing Trade:   14825
# MACD feature | short: 79, long: 316, signal: 5
# Final Asset:     0.0001 | Winning Trade:    3688 | Losing Trade:   13176
# MACD feature | short: 79, long: 316, signal: 6
# Final Asset:     0.0002 | Winning Trade:    3479 | Losing Trade:   11940
# MACD feature | short: 79, long: 316, signal: 7
# Final Asset:     0.0006 | Winning Trade:    3350 | Losing Trade:   11055
# MACD feature | short: 79, long: 316, signal: 8
# Final Asset:     0.0013 | Winning Trade:    3209 | Losing Trade:   10295
# MACD feature | short: 79, long: 316, signal: 9
# Final Asset:     0.0027 | Winning Trade:    3090 | Losing Trade:    9666
# MACD feature | short: 80, long: 240, signal: 4
# Final Asset:     0.0000 | Winning Trade:    4167 | Losing Trade:   15153
# MACD feature | short: 80, long: 240, signal: 5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-1b82e1792199> in <module>
#       1 vwap_result = vwap_trading_test()
#       2 rsi_result = rsi_trading_test()
# ----> 3 macd_result = macd_trading_test()
#
# <ipython-input-10-3d5bf790d4c1> in macd_trading_test(initial_asset, sell_fee, buy_fee)
#      33
#      34         for i, row in s_coin_data.iterrows():
# ---> 35             date, price, macd_diff = row['date'], row['prc'], row['MACD_diff']
#      36
#      37             if sell_signal:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in __getitem__(self, key)
#     880
#     881         elif key_is_scalar:
# --> 882             return self._get_value(key)
#     883
#     884         if is_hashable(key):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in _get_value(self, label, takeable)
#     988         # Similar to Index.get_value, but we do not fall back to positional
#     989         loc = self.index.get_loc(label)
# --> 990         return self.index._get_values_for_loc(self, loc, label)
#     991
#     992     def __setitem__(self, key, value):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in _get_values_for_loc(self, series, loc, key)
#    4631         """
#    4632         if is_integer(loc):
# -> 4633             return series._values[loc]
#    4634
#    4635         return series.iloc[loc]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in _values(self)
#     538         return self._mgr.external_values()
#     539
# --> 540     @property
#     541     def _values(self):
#     542         """
#
# KeyboardInterrupt:

# %%
with open('rsi_100200', 'wb') as f:
    pickle.dump(rsi_result, f)
